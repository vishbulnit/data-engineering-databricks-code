# %% [markdown]
# # Adding refund data - via txt file

# %%
# %fs ls /Workspace/Users/vishwakarmavm91@gmail.com/databrics_course/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs ls 'abfss://gizmobox@datastorageexternalcon.dfs.core.windows.net/landing/external_data/refunds/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://gizmobox@datastorageexternalcon.dfs.core.windows.net/landing/external_data/refunds/refund.txt</td><td>refund.txt</td><td>687</td><td>1783530378000</td></tr></tbody></table></div>

# %%
# %sql
create table if not exists gizmobox.bronze.refunds
(
refund_id integer,
payment_id integer,
refund_timestamp timestamp,
refund_amount decimal(10,2),
refund_reason string
)
using csv
options (
    header = "true",
    delimiter = ","
)
location 'abfss://gizmobox@datastorageexternalcon.dfs.core.windows.net/landing/external_data/refunds/refund.txt';

# %%
# %sql
select * from gizmobox.bronze.refunds;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
REFRESH TABLE gizmobox.bronze.refunds;
